# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizeruu
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# e:\DATASET_KAGLE_MOVIE_RECOM\code_file.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:/e%3A/DATASET_KAGLE_MOVIE_RECOM/code_file.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/e%3A/DATASET_KAGLE_MOVIE_RECOM/code_file.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/e%3A/DATASET_KAGLE_MOVIE_RECOM/code_file.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from sklearn.feature_extraction.text import TfidfVectorizeruu
#
# ImportError: cannot import name 'TfidfVectorizeruu' from 'sklearn.feature_extraction.text' (e:\DATASET_KAGLE_MOVIE_RECOM\myenv\Lib\site-packages\sklearn\feature_extraction\text.py)

# %%
data1= pd.read_csv(r'E:\DATASET_KAGLE_MOVIE_RECOM\tmdb_5000_credits.csv')
data2 =pd.read_csv(r'E:\DATASET_KAGLE_MOVIE_RECOM\tmdb_5000_movies.csv')

# %%
data1.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
data2.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
data1.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
data1.shape
# Out:
# (4803, 4)

# %%
data2.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
data2.shape
# Out:
# (4803, 19)

# %%
mdata = pd.merge(data1 , data2 , left_on ='movie_id', right_on='id', how='inner')

# %%
mdata.shape
# Out:
# (4803, 23)

# %%
mdata.head(5)
# Out:
#    movie_id                                   title_x  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  245000000
# ...

# %%
mdata.columns
# Out:
# Index(['movie_id', 'title_x', 'cast', 'crew', 'budget', 'genres', 'homepage',
#        'id', 'keywords', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'title_y', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
C = mdata['vote_average'].mean()
C
# Out:
# 6.092171559442016

# %%
m = mdata['vote_count'].quantile(0.9)
m
# Out:
# 1838.4000000000015

# %%
Q_movies = mdata.copy().loc[mdata['vote_count'] >=m]
Q_movies
# Out:
#       movie_id                                   title_x  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4291       176                                       Saw
# 4300       500                            Reservoir Dogs
# 4302       429            The Good, the Bad and the Ugly
# 4337       103                               Taxi Driver
# 4602       389                              12 Angry Men
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
Q_movies.shape
# Out:
# (481, 23)

# %%
def weighted_rating(x,C=C,m=m):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m)*R)+(m/(v+m)*C)

# %%
Q_movies['score'] =Q_movies.apply(weighted_rating,axis=1)

# %%
Q_movies.shape
# Out:
# (481, 24)

# %%
Q_movies.head()
# Out:
#    movie_id                                   title_x  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  245000000
# ...

# %%
Q_movies = Q_movies.sort_values('score',ascending= False)
Q_movies[['title_x','vote_count','vote_average','score']].head(10)
# Out:
#                                             title_x  vote_count  vote_average  \
# 1881                       The Shawshank Redemption        8205           8.5
# 662                                      Fight Club        9413           8.3
# 65                                  The Dark Knight       12002           8.2
# 3232                                   Pulp Fiction        8428           8.3
# 96                                        Inception       13752           8.1
# 3337                                  The Godfather        5893           8.4
# 95                                     Interstellar       10867           8.1
# 809                                    Forrest Gump        7927           8.2
# 329   The Lord of the Rings: The Return of the King        8064           8.1
# 1990                        The Empire Strikes Back        5879           8.2
#
#          score
# 1881  8.059258
# 662   7.939256
# 65    7.920020
# 3232  7.904645
# 96    7.863239
# ...

# %%
mdata.columns
# Out:
# Index(['movie_id', 'title_x', 'cast', 'crew', 'budget', 'genres', 'homepage',
#        'id', 'keywords', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'title_y', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
pop = mdata.sort_values('popularity',ascending = False)
plt.figure(figsize=(15,4))

x_axis = (pop['title_x'].head(6))
y_axis = (pop['popularity'].head(6))
plt.bar(x_axis,y_axis)
plt.title('title name')
plt.xlabel('x_axis name')
plt.ylabel('y_axis name')
plt.show()

# %%
mdata['overview'].head()
# Out:
# 0    In the 22nd century, a paraplegic Marine is di...
# 1    Captain Barbossa, long believed to be dead, ha...
# 2    A cryptic message from Bondâ€™s past sends him...
# 3    Following the death of District Attorney Harve...
# 4    John Carter is a war-weary, former military ca...
# Name: overview, dtype: object

# %%
#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf =TfidfVectorizer(stop_words="english")

#Replace NaN with an empty string
mdata['overview']=mdata['overview'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(mdata['overview'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (4803, 21260)

# %%
from sklearn.metrics.pairwise import linear_kernel


# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(mdata.index,index=mdata['title_x']).drop_duplicates()

# %%
# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title_x, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title_x]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return mdata['title_x'].iloc[movie_indices]

# %%
get_recommendations('Avatar')
# Out:
# 3604                       Apollo 18
# 2130                    The American
# 634                       The Matrix
# 1341            The Inhabited Island
# 529                 Tears of the Sun
# 1610                           Hanna
# 311     The Adventures of Pluto Nash
# 847                         Semi-Pro
# 775                        Supernova
# 2628             Blood and Chocolate
# Name: title_x, dtype: object

# %%
get_recommendations('The Dark Knight Rises')
# Out:
# 65                              The Dark Knight
# 299                              Batman Forever
# 428                              Batman Returns
# 1359                                     Batman
# 3854    Batman: The Dark Knight Returns, Part 2
# 119                               Batman Begins
# 2507                                  Slow Burn
# 1181                                        JFK
# 210                              Batman & Robin
# 9            Batman v Superman: Dawn of Justice
# Name: title_x, dtype: object

# %%
from ast import literal_eval

features = ['cast','crew','keywords','genres']
for feature in features:
    mdata[feature]=mdata[feature].apply(literal_eval)

# %%
mdata.columns
# Out:
# Index(['movie_id', 'title_x', 'cast', 'crew', 'budget', 'genres', 'homepage',
#        'id', 'keywords', 'original_language', 'original_title', 'overview',
#        'popularity', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'title_y', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
mdata[['title_x','cast','keywords','genres']].head(3)
# Out:
#                                     title_x  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
# 1  [{'cast_id': 4, 'character': 'Captain Jack Spa...
# 2  [{'cast_id': 1, 'character': 'James Bond', 'cr...
#
#                                             keywords  \
# 0  [{'id': 1463, 'name': 'culture clash'}, {'id':...
# 1  [{'id': 270, 'name': 'ocean'}, {'id': 726, 'na...
# 2  [{'id': 470, 'name': 'spy'}, {'id': 818, 'name...
#
#                                               genres
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...

# %% [markdown]
# Get directors name from the crew feature

# %%
def get_director(x):
    for i in x:
        if i['job']=="director":
            return i['name']
    return np.nan

# %% [markdown]
# Return the list  or top 3 elements or entire list

# %%
def get_list(x):
    if isinstance(x,list):
        names=[i['name']for i in x]
        # check if more than 3 elements exist ,IF yes ,return onlu first three.if not ,return entire list 
        if len(names) > 3:
            names = names[:3]
        return names
    return[]

# %% [markdown]
# Define new director,cast,genres and keywords feature that are in a suitable form

# %%
mdata['Director'] = mdata['crew'].apply(get_director)

features = ['cast','keywords','genres']
for feature in features:
    mdata[feature] = mdata[feature].apply(get_list)

# %%
mdata[['title_x','cast','keywords','genres','Director']].head(3)
# Out:
#                                     title_x  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]
#
#                               keywords                        genres  Director
# 0   [culture clash, future, space war]  [Action, Adventure, Fantasy]       NaN
# 1   [ocean, drug abuse, exotic island]  [Adventure, Fantasy, Action]       NaN
# 2  [spy, based on novel, secret agent]    [Action, Adventure, Crime]       NaN

# %%
mdata['Director'].isnull().sum()
# Out:
# 4803

# %%
mdata['Director']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4798   NaN
# 4799   NaN
# 4800   NaN
# 4801   NaN
# 4802   NaN
# Name: Director, Length: 4803, dtype: float64

# %%
def clean_data(x):
    if isinstance(x,list):
        return[str.lower(i.replace(" ","")) for i in x ]
    else:
        # check if director exista .If not ,return empty string
        if isinstance(x,str):
            return str.lower(x.replace(" ",""))
        else:
            return ''

# %%
features = ['cast','keywords','genres','Director']

for feature in features:
    mdata[feature] =mdata[feature].apply(clean_data)

# %%
def create_soup(x):
    return ''.join(x['keywords']) + ' '.join(x['cast'])+ ' '+x['Director']+ ' ' +' '.join(x['genres'])
mdata['soup']= mdata.apply(create_soup,axis =1)

# %%
# import countVectorizer and create the count matrix

from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(mdata['soup'])

# %% [markdown]
# Compute the Cosine Similarity matrix based on the count_matrix

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosin_sim2 = cosine_similarity(count_matrix,count_matrix)

# %% [markdown]
# Reset index of our main DataFrame and construct reverse mapping an before

# %%
mdata = mdata.reset_index()
indices = pd.Series(mdata.index,index=mdata['title_x'])

# %%
get_recommendations('The Dark Knight Rises', cosin_sim2)
# Out:
# 4638                 Amidst the Devil's Wings
# 119                             Batman Begins
# 65                            The Dark Knight
# 405     The Fast and the Furious: Tokyo Drift
# 510                           Children of Men
# 629                            Need for Speed
# 747                            Gangster Squad
# 761                            Righteous Kill
# 762                            Mercury Rising
# 982                             Run All Night
# Name: title_x, dtype: object

# %%
get_recommendations('The Godfather',cosin_sim2)
# Out:
# 1394                      Donnie Brasco
# 2649                  The Son of No One
# 4638           Amidst the Devil's Wings
# 4564           Straight Out of Brooklyn
# 281                   American Gangster
# 588     Wall Street: Money Never Sleeps
# 877                          Black Mass
# 883                 Catch Me If You Can
# 892                              Casino
# 1149                    American Hustle
# Name: title_x, dtype: object
